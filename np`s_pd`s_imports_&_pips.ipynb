# %% [markdown]
# ## Pips ##

# %%
#pip install numpy
#pip install pandas
#pip install matplotlib
#pip install seaborn
#pip install scikit-learn
#pip install plotly ipywidgets
#pip install scipy
#pip install statsmodels

# %% [markdown]
# ## Imports ##

# %%
import numpy as np
import pandas as pd
from numpy import random
from sys import getsizeof
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Np`s and Np topics ##

# %%
#Create and indexing array
#Fancy indexig
#Data types
#Multi-dimensional arrays
#Multi-dimensional arrays
#Create placeholder arrays
#Range and linspace
#Reshape
#Transposition
#Vectorization
#Inf, NaN
#choice
#Uniform distribution
#Statistics methods
#Boolean arrays
#and
#not
#any, all



# np.int32 / np.int8
# var.itemsize — это атрибут в NumPy, который возвращает размер одного элемента в массиве в байтах.
# var.dtype — это атрибут в NumPy, который возвращает объект типа данных элементов массива. 
# - Он показывает, какого типа данные хранятся в массиве (например, целые числа, числа с плавающей запятой, строки и т.д.).
# np.fromstring — это функция в NumPy, которая преобразует строку данных в массив. 
# - Однако с версии NumPy 1.14 её использование для работы с текстовыми строками было прекращено, и теперь она лучше работает с двоичными данными.
# arr.ndim — это атрибут в NumPy, который возвращает количество измерений (или осей) массива NumPy.
# arr.shape - возвращает кортеж, который представляет собой размеры (или форму) массива по каждой оси.
# arr.size - возвращает общее количество элементов в массиве, независимо от его формы.
# np.random.rand(d0, d1, ..., dn) - используется для генерации массива случайных чисел с плавающей запятой от 0 до 1, распределённых по равномерному закону.
# np.random.randint(low, high=None, size=None, dtype=int) - используется для генерации случайных целых чисел из указанного диапазона.
# varArr = np.random.randint(num, num, size=(num,num,num)) - random integers in array
# np.zeros(shape, dtype=float, order='C') - используется для создания массива, заполненного нулями. 
# - Эта функция полезна, когда нужно инициализировать массив с известной формой, 
# - но с элементами, равными нулю.
# np.ones(shape, dtype=float, order='C') - используется для создания массива, заполненного единицами. 
# - Эта функция аналогична np.zeros, но вместо нулей все элементы массива равны 1.
# np.full(shape, fill_value, dtype=None, order='C') - используется для создания массива заданной формы и заполнения его указанным значением.
# np.eye(N, M=None, k=0, dtype=float, order='C') - используется для создания двумерной единичной матрицы. 
# - Единичная матрица — это квадратная матрица с единицами на главной диагонали и нулями во всех остальных позициях.
# np.ones_like(a, dtype=None, order='K', subok=True, shape=None) - создаёт новый массив той же формы и типа данных, что и переданный массив, но заполненный единицами.
# np.pi — это константа в библиотеке NumPy, которая представляет значение числа π (пи), приблизительно равного 3.14159. 
# - Это стандартное значение, используемое во многих математических и научных расчетах.

# np.arange([start,] stop, [step,] dtype=None) - np.arange в NumPy используется для создания одномерного массива с равномерно распределёнными значениями в заданном диапазоне. 
# - Это аналог функции range в Python, но с возможностью работы с массивами NumPy.
# np.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None) - используется для создания одномерного массива с равномерно распределёнными значениями между двумя заданными числами. В отличие от np.arange, 
# - которая использует шаг для определения значений, np.linspace генерирует фиксированное количество значений в указанном диапазоне.
# varArr.reshape(num,num,...) - reshape of a varArr
# varArr[num, num] = num/str/float - enters a definition in defined index
# varArr.base - ?
# varArr.flatten()
# random.choice(arr, size=(10,10)) - 
# random.uniform(num, num)
# random.seed(num)
# varArr.prod()
# np.mean()
# np.median()
# np.sort()
# varArr.var() # dispersion/variation
# varArr.std() # standart diviation
# varArr.any()
# varArr.all
# varArr.isin(varArr1, varArr2)
# np.random.binomial(n=num, p=num, size=100)
# np.random.normal(loc=,scale=,size=)
# np.math.factorial()
# np.math.perm()
# np.math.comb()
# module itertools: 'from itertools import combinations, permutations' - adds functions 'combinations()' and 'permutations()'

# %% [markdown]
# ## Pd`s and Pd topics ##

# %%
#Series
#DataFrame
#Indexing, Slicing
#Drop
#Operations (Math and logic)
#Modifying DataFrame
#Modifying DataFrame
#Index Changing
#Statistic methods
#Corelation
#Between
#select dtypes
#nlargest / nsmallest
#replace
#map & apply
#cut
#Sorting
#Groupby
#Pivot table




#pd.Series(data=None, index=None, dtype=None, name=None, copy=False, fastpath=False) # Creates one dimensional array with indexes
#var.index = var = ['Definitions', 'and', 'values' 'in', 'strings'] # changes index by values of other var.
#var.name = 'String' # changes/creates name of the Series
#var.values # calls a casual array with values exactly as var = np.array(var)
#var.iloc[numIndex] = returns data by numIndex defined within
#df.loc[row_labels, column_labels] # returns data by rowIndex, or columnIndex in data frame
#var['Index'/IndexNum] = int/float/str # gives a value to the row of Series according to index defined
#var = pd.DataFrame(data=None, index=None, columns=None, dtype=None, copy=False) # creates a data frame in a cross-section format from a values and definitions -->
# <-- defined in otherVar (dict), (list), (Array), (Series), (Outer CSV`s, Excel & so on)
#var.size # gives a size of definitions
#var.columns # returns columns from data frame
#var.info() # returns common information of dataframe
#var.describe() # gives main statistical values of dataframe
#var.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last') # sorts values according to argument inside 
#df.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise') # removes rows or columns
#lambda arg: expression # one time function wth only one expression
#df.rename(mapper=None, *, index=None, columns=None, axis=None, copy=True, inplace=False, level=None, errors='ignore') - 
# - Функция df.rename() в pandas используется для изменения названий строк (индексов) или столбцов в DataFrame. 
# - Это удобно, если вы хотите переименовать один или несколько столбцов, а также строки индекса.
#df.reset_index(level=None, drop=False, inplace=False, col_level=0, col_fill='') - 
# - Функция df.reset_index() в pandas используется для сброса текущего индекса DataFrame и 
# - возвращения его к состоянию по умолчанию (обычно это числовой индекс). 
# - При этом старый индекс может быть добавлен в DataFrame как один из столбцов.
#df.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False) - 
# - Функция df.set_index() в pandas используется для установки одного или нескольких столбцов DataFrame в качестве индекса. 
# - Она позволяет заменить существующий индекс одним из столбцов или несколькими столбцами, превращая их в индекс DataFrame.
#df.sum(axis=None, skipna=True, level=None, numeric_only=None, min_count=0) -
# - Функция df.sum() в pandas используется для суммирования значений по столбцам или строкам в DataFrame. 
# - Она возвращает сумму значений числовых столбцов по умолчанию, но может быть настроена для работы с различными осями и типами данных.
#df.max(axis=None, skipna=True, level=None, numeric_only=None) - 
# - Функция df.max() в pandas используется для нахождения максимальных значений в DataFrame по столбцам или строкам. 
# - По умолчанию она возвращает максимальные значения для каждого столбца, но может быть настроена для работы по строкам.
#df.mean(axis=None, skipna=True, level=None, numeric_only=None) - 
# - Функция df.mean() в pandas используется для вычисления среднего арифметического значений по столбцам или строкам в DataFrame. 
# - Она возвращает средние значения числовых столбцов по умолчанию, но может быть настроена для работы с другими осями.
#df.median(axis=None, skipna=True, level=None, numeric_only=None) - 
# - Функция df.median() в pandas используется для вычисления медианы значений по столбцам или строкам в DataFrame. 
# - Медиана — это центральное значение в отсортированном наборе данных, которое разделяет данные на две равные части. 
# - Как и другие агрегатные функции pandas, df.median() может работать как по столбцам, так и по строкам.
#df.mode(axis=0, numeric_only=False, dropna=True) - 
# - Функция df.mode() в pandas используется для нахождения моды (наиболее часто встречающихся значений) в каждом столбце или строке DataFrame.
# - Мода — это значение, которое встречается наиболее часто. В случае, если таких значений несколько, функция возвращает все моды.
#df.quantile(q=0.5, axis=0, numeric_only=True, interpolation='linear') - 
# - Функция df.quantile() в pandas используется для вычисления квантили значений по строкам или столбцам в DataFrame.
# - Квантиль — это значение, ниже которого лежит определённая доля данных. 
# - Например, медиана — это 0.5-квантиль (50%), которая разделяет данные пополам.
#df.corr(method='pearson', min_periods=1, numeric_only=False) - 
# - Функция df.corr() в pandas используется для вычисления корреляционной матрицы между столбцами DataFrame. 
# - Корреляция измеряет степень зависимости между переменными, где значения варьируются от -1 до 1:
# - 1: Сильная положительная корреляция (когда одна переменная увеличивается, другая также увеличивается).
# - 0: Отсутствие корреляции (никакой зависимости между переменными).
# - -1: Сильная отрицательная корреляция (когда одна переменная увеличивается, другая уменьшается).
#pd.read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, encoding=None, compression='infer', ... )
# - Функция pd.read_csv() в pandas используется для чтения данных из CSV-файла и их преобразования в DataFrame.
#df.head(n=5) - Функция df.head() в pandas используется для отображения первых нескольких строк DataFrame.
# df.tail(n=5) - Функция df.tail() в pandas используется для отображения последних нескольких строк DataFrame. 
# df.sample(n=None, frac=None, replace=False, weights=None, random_state=None, axis=None) - 
# - Функция df.sample() в pandas используется для выборки случайных строк или столбцов из DataFrame.
#df/Series.value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True) - 
# - Функция .value_counts() в pandas используется для подсчета частоты уникальных значений в столбце или серии.
#df/Series['column_name'].unique() - Функция df['column_name'].unique() в pandas используется для получения массива уникальных значений из указанного столбца DataFrame.
#df.isin(values) - Функция df.isin() в pandas используется для фильтрации данных в DataFrame на основе того, содержатся ли значения в указанном списке или наборе.
#df.min(axis=0, skipna=True, numeric_only=False) - Функция df.min() в pandas используется для нахождения минимальных значений в каждом столбце или строке DataFrame.
#df.max(axis=0, skipna=True, numeric_only=False) - Функция df.max() в pandas используется для нахождения максимальных значений по каждому столбцу или строке в DataFrame.
#df.std(axis=0, skipna=True, ddof=1, numeric_only=False) - Функция .std() в pandas используется для вычисления стандартного отклонения значений в каждом столбце или строке DataFrame.
#df/Series.between(left, right, inclusive="both") - Функция .between() в pandas используется для проверки, находятся ли значения в столбце или серии в пределах указанного диапазона.
#df.select_dtypes(include=None, exclude=None) - Функция df.select_dtypes() в pandas используется для выбора столбцов DataFrame на основе их типа данных.
#df.dtypes - Функция df.dtypes в pandas используется для отображения типов данных каждого столбца в DataFrame.
#df.nlargest(n, columns, keep='first'/'last'/'all') - Функция df.nlargest() в pandas используется для выбора строк DataFrame с самыми большими значениями в одном или нескольких столбцах.
#df.nsmallest(n, columns, keep='first'/'last'/'all') - Функция df.nsmallest() в pandas используется для выбора строк DataFrame с наименьшими значениями в одном или нескольких столбцах.
#df.replace(to_replace=None, value=None, inplace=False, limit=None, regex=False, method='pad'/'ffill'/'bfill') -
# - Функция df.replace() в pandas используется для замены определенных значений в DataFrame или Series. 
#Series(Only!).map(arg, na_action=None) - Функция df.map() в pandas применяется к объектам Series для замены значений на основе переданной функции, словаря или серии.
#df.applymap(func) - Функция applymap() в pandas применяется к каждому элементу DataFrame и позволяет использовать произвольную функцию для обработки каждого элемента. 
#df.apply(func, axis=0, raw=False, result_type('axis=1' Only!)=None/'expand'/'reduce'/'broadcast') - 
# - Функция apply() в pandas используется для применения функции к каждой строке или столбцу в DataFrame или к значениям в Series. 
#- Она может применяться как к столбцам
#df.insert(loc, column, value, allow_duplicates=False) - Функция df.insert() в pandas используется для добавления нового столбца в определенную позицию DataFrame.
